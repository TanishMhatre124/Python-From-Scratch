# %% [markdown]
# **information of data   ------->   info() method**
# #problem:
# 1.columns, rows
# 2.what is type of?
# 3.missing data ?
#
# info() method gives:------>
#
#  rows column ,column name , int, float, non null, memory usage of data frame

# %%
df=pd.read_json(r"..\Datasets\sample_Data.json")

print("display info of data")
print(df.info())
# Out:
# display info of data
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           20 non-null     int64
#  1   name         20 non-null     str
#  2   description  20 non-null     str
#  3   price        20 non-null     float64
#  4   category     20 non-null     str
#  5   image        20 non-null     str
# dtypes: float64(1), int64(1), str(4)
# memory usage: 1.1 KB
# None
